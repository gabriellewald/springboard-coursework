# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
# Understanding what the dataframe looks like -- number of rows and columns
properties.shape
# Out:
# (305, 49)

# %%
# .head() shows us a small sample of the data, default value is 5
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0          E12000003     E12000004     E12000005       E12000006  E12000007
# 1            44803.4       45544.5       48527.5         56701.6    74435.8
# 2            44528.8       46051.6       49341.3         56593.6    72777.9
# 3            45200.5       45383.8       49442.2         56171.2    73896.8
# 4            45614.3       46124.2       49455.9         56567.9    74455.3
#
#   SOUTH EAST SOUTH WEST Unnamed: 47    England
# 0  E12000008  E12000009         NaN  E92000001
# 1    64018.9    54705.2         NaN    53202.8
# 2      63715    54356.1         NaN    53096.2
# 3    64113.6    53583.1         NaN    53201.3
# 4    64623.2      54786         NaN    53590.9
#
# [5 rows x 49 columns]

# %%
# .tail() shows us a small sample of the data, default value is 5
properties.tail()
# Out:
#     Unnamed: 0 City of London Barking & Dagenham  Barnet  Bexley   Brent  \
# 300 2019-12-01         737275             301283  519306  336302  427126
# 301 2020-01-01         747611             303653  518542  334765  423161
# 302 2020-02-01         777640             304265  519121  337760  467145
# 303 2020-03-01         844989             304099  527747  339215  461398
# 304 2020-04-01         867841             283139  526553  346840  494455
#
#     Bromley  Camden Croydon  Ealing  ... NORTH WEST YORKS & THE HUMBER  \
# 300  438682  807124  369568  469662  ...     164893             165818
# 301  435532  815512  371227  466491  ...     165094             164752
# 302  435704  825249  371357  465614  ...     166291             164949
# 303  434625  870107  370872  478565  ...     168161             165685
# 304  443482  870627  386738  502107  ...     167809             165561
#
#     EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  LONDON SOUTH EAST SOUTH WEST  \
# 300        194553        198644          290814  478576     321972     256577
# 301        196199        202085          290335  478489     323422     257822
# 302        194214        200196          290309  479628     319827     257101
# 303        198284        201369          291356  488185     326701     262444
# 304        200513        202093          295640  480425     327413     255891
#
#     Unnamed: 47 England
# 300         NaN  248250
# 301         NaN  248950
# 302         NaN  248232
# 303         NaN  251539
# 304         NaN  250874
#
# [5 rows x 49 columns]

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
# Transpose to have districts as indices and time as columns, df.T or df1.transpose()
properties_transposed = properties.T

# %%
# Check what its rows indexes are
properties_transposed.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001                91449              82202.8
# Barking & Dagenham  E09000002              50460.2              51085.8
# Barnet              E09000003              93284.5              93190.2
# Bexley              E09000004              64958.1              64787.9
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London                  79120.7              77101.2
# Barking & Dagenham                51269              53133.5
# Barnet                          92247.5              90762.9
# Bexley                          64367.5              64277.7
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# City of London                  84409.1              94900.5
# Barking & Dagenham              53042.2              53700.3
# Barnet                            90258              90107.2
# Bexley                          63997.1              64252.3
#
#                                     7                    8    \
# Unnamed: 0          1995-07-01 00:00:00  1995-08-01 00:00:00
# City of London                   110128               112329
# Barking & Dagenham              52113.1              52232.2
# Barnet                          91441.2              92361.3
# Bexley                          63722.7              64432.6
#
#                                     9    ...                  295  \
# Unnamed: 0          1995-09-01 00:00:00  ...  2019-07-01 00:00:00
# City of London                   104473  ...               756407
# Barking & Dagenham              51471.6  ...               297426
# Barnet                          93273.1  ...               514668
# Bexley                          64509.5  ...               338346
#
#                                     296                  297  \
# Unnamed: 0          2019-08-01 00:00:00  2019-09-01 00:00:00
# City of London                   813770               810455
# Barking & Dagenham               299421               304778
# Barnet                           528577               526670
# Bexley                           337523               333340
#
#                                     298                  299  \
# Unnamed: 0          2019-10-01 00:00:00  2019-11-01 00:00:00
# City of London                   826227               776894
# Barking & Dagenham               304579               306390
# Barnet                           525678               522639
# Bexley                           332920               333657
#
#                                     300                  301  \
# Unnamed: 0          2019-12-01 00:00:00  2020-01-01 00:00:00
# City of London                   737275               747611
# Barking & Dagenham               301283               303653
# Barnet                           519306               518542
# Bexley                           336302               334765
#
#                                     302                  303  \
# Unnamed: 0          2020-02-01 00:00:00  2020-03-01 00:00:00
# City of London                   777640               844989
# Barking & Dagenham               304265               304099
# Barnet                           519121               527747
# Bexley                           337760               339215
#
#                                     304
# Unnamed: 0          2020-04-01 00:00:00
# City of London                   867841
# Barking & Dagenham               283139
# Barnet                           526553
# Bexley                           346840
#
# [5 rows x 305 columns]

# %%
# Check what our row indexes are - info we want to analyze should NEVER be in the index!
properties_transposed.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
# verify index 
#Index: 49 entries, Unnamed: 0 to England ---> Need to reset index


properties_transposed.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49 entries, Unnamed: 0 to England
# Data columns (total 305 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       45 non-null     object
#  1   1       46 non-null     object
#  2   2       46 non-null     object
#  3   3       46 non-null     object
#  4   4       46 non-null     object
#  5   5       46 non-null     object
#  6   6       46 non-null     object
#  7   7       46 non-null     object
#  8   8       46 non-null     object
#  9   9       46 non-null     object
#  10  10      46 non-null     object
#  11  11      46 non-null     object
#  12  12      46 non-null     object
#  13  13      46 non-null     object
#  14  14      46 non-null     object
#  15  15      46 non-null     object
#  16  16      46 non-null     object
#  17  17      46 non-null     object
#  18  18      46 non-null     object
#  19  19      46 non-null     object
#  20  20      46 non-null     object
#  21  21      46 non-null     object
#  22  22      46 non-null     object
#  23  23      46 non-null     object
#  24  24      46 non-null     object
#  25  25      46 non-null     object
#  26  26      46 non-null     object
#  27  27      46 non-null     object
#  28  28      46 non-null     object
#  29  29      46 non-null     object
#  30  30      46 non-null     object
#  31  31      46 non-null     object
#  32  32      46 non-null     object
#  33  33      46 non-null     object
#  34  34      46 non-null     object
#  35  35      46 non-null     object
#  36  36      46 non-null     object
#  37  37      46 non-null     object
#  38  38      46 non-null     object
#  39  39      46 non-null     object
#  40  40      46 non-null     object
#  41  41      46 non-null     object
#  42  42      46 non-null     object
#  43  43      46 non-null     object
#  44  44      46 non-null     object
#  45  45      46 non-null     object
#  46  46      46 non-null     object
#  47  47      46 non-null     object
#  48  48      46 non-null     object
#  49  49      46 non-null     object
#  50  50      46 non-null     object
#  51  51      46 non-null     object
#  52  52      46 non-null     object
#  53  53      46 non-null     object
#  54  54      46 non-null     object
#  55  55      46 non-null     object
#  56  56      46 non-null     object
#  57  57      46 non-null     object
#  58  58      46 non-null     object
#  59  59      46 non-null     object
#  60  60      46 non-null     object
#  61  61      46 non-null     object
#  62  62      46 non-null     object
#  63  63      46 non-null     object
#  64  64      46 non-null     object
#  65  65      46 non-null     object
#  66  66      46 non-null     object
#  67  67      46 non-null     object
#  68  68      46 non-null     object
#  69  69      46 non-null     object
#  70  70      46 non-null     object
#  71  71      46 non-null     object
#  72  72      46 non-null     object
#  73  73      46 non-null     object
#  74  74      46 non-null     object
#  75  75      46 non-null     object
#  76  76      46 non-null     object
#  77  77      46 non-null     object
#  78  78      46 non-null     object
#  79  79      46 non-null     object
#  80  80      46 non-null     object
#  81  81      46 non-null     object
#  82  82      46 non-null     object
#  83  83      46 non-null     object
#  84  84      46 non-null     object
#  85  85      46 non-null     object
#  86  86      46 non-null     object
#  87  87      46 non-null     object
#  88  88      46 non-null     object
#  89  89      46 non-null     object
#  90  90      46 non-null     object
#  91  91      46 non-null     object
#  92  92      46 non-null     object
#  93  93      46 non-null     object
#  94  94      46 non-null     object
#  95  95      46 non-null     object
#  96  96      46 non-null     object
#  97  97      46 non-null     object
#  98  98      46 non-null     object
#  99  99      46 non-null     object
#  100 100     46 non-null     object
#  101 101     46 non-null     object
#  102 102     46 non-null     object
#  103 103     46 non-null     object
#  104 104     46 non-null     object
#  105 105     46 non-null     object
#  106 106     46 non-null     object
#  107 107     46 non-null     object
#  108 108     46 non-null     object
#  109 109     46 non-null     object
#  110 110     46 non-null     object
#  111 111     46 non-null     object
#  112 112     46 non-null     object
#  113 113     46 non-null     object
#  114 114     46 non-null     object
#  115 115     46 non-null     object
#  116 116     46 non-null     object
#  117 117     46 non-null     object
#  118 118     46 non-null     object
#  119 119     46 non-null     object
#  120 120     46 non-null     object
#  121 121     46 non-null     object
#  122 122     46 non-null     object
#  123 123     46 non-null     object
#  124 124     46 non-null     object
#  125 125     46 non-null     object
#  126 126     46 non-null     object
#  127 127     46 non-null     object
#  128 128     46 non-null     object
#  129 129     46 non-null     object
#  130 130     46 non-null     object
#  131 131     46 non-null     object
#  132 132     46 non-null     object
#  133 133     46 non-null     object
#  134 134     46 non-null     object
#  135 135     46 non-null     object
#  136 136     46 non-null     object
#  137 137     46 non-null     object
#  138 138     46 non-null     object
#  139 139     46 non-null     object
#  140 140     46 non-null     object
#  141 141     46 non-null     object
#  142 142     46 non-null     object
#  143 143     46 non-null     object
#  144 144     46 non-null     object
#  145 145     46 non-null     object
#  146 146     46 non-null     object
#  147 147     46 non-null     object
#  148 148     46 non-null     object
#  149 149     46 non-null     object
#  150 150     46 non-null     object
#  151 151     46 non-null     object
#  152 152     46 non-null     object
#  153 153     46 non-null     object
#  154 154     46 non-null     object
#  155 155     46 non-null     object
#  156 156     46 non-null     object
#  157 157     46 non-null     object
#  158 158     46 non-null     object
#  159 159     46 non-null     object
#  160 160     46 non-null     object
#  161 161     46 non-null     object
#  162 162     46 non-null     object
#  163 163     46 non-null     object
#  164 164     46 non-null     object
#  165 165     46 non-null     object
#  166 166     46 non-null     object
#  167 167     46 non-null     object
#  168 168     46 non-null     object
#  169 169     46 non-null     object
#  170 170     46 non-null     object
#  171 171     46 non-null     object
#  172 172     46 non-null     object
#  173 173     46 non-null     object
#  174 174     46 non-null     object
#  175 175     46 non-null     object
#  176 176     46 non-null     object
#  177 177     46 non-null     object
#  178 178     46 non-null     object
#  179 179     46 non-null     object
#  180 180     46 non-null     object
#  181 181     46 non-null     object
#  182 182     46 non-null     object
#  183 183     46 non-null     object
#  184 184     46 non-null     object
#  185 185     46 non-null     object
#  186 186     46 non-null     object
#  187 187     46 non-null     object
#  188 188     46 non-null     object
#  189 189     46 non-null     object
#  190 190     46 non-null     object
#  191 191     46 non-null     object
#  192 192     46 non-null     object
#  193 193     46 non-null     object
#  194 194     46 non-null     object
#  195 195     46 non-null     object
#  196 196     46 non-null     object
#  197 197     46 non-null     object
#  198 198     46 non-null     object
#  199 199     46 non-null     object
#  200 200     46 non-null     object
#  201 201     46 non-null     object
#  202 202     46 non-null     object
#  203 203     46 non-null     object
#  204 204     46 non-null     object
#  205 205     46 non-null     object
#  206 206     46 non-null     object
#  207 207     46 non-null     object
#  208 208     46 non-null     object
#  209 209     46 non-null     object
#  210 210     46 non-null     object
#  211 211     46 non-null     object
#  212 212     46 non-null     object
#  213 213     46 non-null     object
#  214 214     46 non-null     object
#  215 215     46 non-null     object
#  216 216     46 non-null     object
#  217 217     46 non-null     object
#  218 218     46 non-null     object
#  219 219     46 non-null     object
#  220 220     46 non-null     object
#  221 221     46 non-null     object
#  222 222     46 non-null     object
#  223 223     46 non-null     object
#  224 224     46 non-null     object
#  225 225     46 non-null     object
#  226 226     46 non-null     object
#  227 227     46 non-null     object
#  228 228     46 non-null     object
#  229 229     46 non-null     object
#  230 230     46 non-null     object
#  231 231     46 non-null     object
#  232 232     46 non-null     object
#  233 233     46 non-null     object
#  234 234     46 non-null     object
#  235 235     46 non-null     object
#  236 236     46 non-null     object
#  237 237     46 non-null     object
#  238 238     46 non-null     object
#  239 239     46 non-null     object
#  240 240     46 non-null     object
#  241 241     46 non-null     object
#  242 242     46 non-null     object
#  243 243     46 non-null     object
#  244 244     46 non-null     object
#  245 245     46 non-null     object
#  246 246     46 non-null     object
#  247 247     46 non-null     object
#  248 248     46 non-null     object
#  249 249     46 non-null     object
#  250 250     46 non-null     object
#  251 251     46 non-null     object
#  252 252     46 non-null     object
#  253 253     46 non-null     object
#  254 254     46 non-null     object
#  255 255     46 non-null     object
#  256 256     46 non-null     object
#  257 257     46 non-null     object
#  258 258     46 non-null     object
#  259 259     46 non-null     object
#  260 260     46 non-null     object
#  261 261     46 non-null     object
#  262 262     46 non-null     object
#  263 263     46 non-null     object
#  264 264     46 non-null     object
#  265 265     46 non-null     object
#  266 266     46 non-null     object
#  267 267     46 non-null     object
#  268 268     46 non-null     object
#  269 269     46 non-null     object
#  270 270     46 non-null     object
#  271 271     46 non-null     object
#  272 272     46 non-null     object
#  273 273     46 non-null     object
#  274 274     46 non-null     object
#  275 275     46 non-null     object
#  276 276     46 non-null     object
#  277 277     46 non-null     object
#  278 278     46 non-null     object
#  279 279     46 non-null     object
#  280 280     46 non-null     object
#  281 281     46 non-null     object
#  282 282     46 non-null     object
#  283 283     46 non-null     object
#  284 284     46 non-null     object
#  285 285     46 non-null     object
#  286 286     46 non-null     object
#  287 287     46 non-null     object
#  288 288     46 non-null     object
#  289 289     46 non-null     object
#  290 290     46 non-null     object
#  291 291     46 non-null     object
#  292 292     46 non-null     object
#  293 293     46 non-null     object
#  294 294     46 non-null     object
#  295 295     46 non-null     object
#  296 296     46 non-null     object
#  297 297     46 non-null     object
#  298 298     46 non-null     object
#  299 299     46 non-null     object
#  300 300     46 non-null     object
#  301 301     46 non-null     object
#  302 302     46 non-null     object
#  303 303     46 non-null     object
#  304 304     46 non-null     object
# dtypes: object(305)
# memory usage: 118.4+ KB

# %%
# Use reset_index()

properties_transposed = properties_transposed.reset_index()

# %%
# Check the dataframe
properties_transposed.head()
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
# 3              90107.2              91441.2              92361.3  ...
# 4              64252.3              63722.7              64432.6  ...
#
#                    295                  296                  297  \
# 0  2019-07-01 00:00:00  2019-08-01 00:00:00  2019-09-01 00:00:00
# 1               756407               813770               810455
# 2               297426               299421               304778
# 3               514668               528577               526670
# 4               338346               337523               333340
#
#                    298                  299                  300  \
# 0  2019-10-01 00:00:00  2019-11-01 00:00:00  2019-12-01 00:00:00
# 1               826227               776894               737275
# 2               304579               306390               301283
# 3               525678               522639               519306
# 4               332920               333657               336302
#
#                    301                  302                  303  \
# 0  2020-01-01 00:00:00  2020-02-01 00:00:00  2020-03-01 00:00:00
# 1               747611               777640               844989
# 2               303653               304265               304099
# 3               518542               519121               527747
# 4               334765               337760               339215
#
#                    304
# 0  2020-04-01 00:00:00
# 1               867841
# 2               283139
# 3               526553
# 4               346840
#
# [5 rows x 306 columns]

# %%
# To confirm that our DataFrame's columns are mainly just integers, call the .columns feature on our DataFrame:
properties_transposed.columns
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            295,     296,     297,     298,     299,     300,     301,     302,
#            303,     304],
#       dtype='object', length=306)

# %%
# The iloc[] method with double square brackets on the properties_transposed DataFrame, to see the row at index 0. 
properties_transposed.iloc[[0]]
# Out:
#         index    0                    1                    2  \
# 0  Unnamed: 0  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
#
#                    295                  296                  297  \
# 0  2019-07-01 00:00:00  2019-08-01 00:00:00  2019-09-01 00:00:00
#
#                    298                  299                  300  \
# 0  2019-10-01 00:00:00  2019-11-01 00:00:00  2019-12-01 00:00:00
#
#                    301                  302                  303  \
# 0  2020-01-01 00:00:00  2020-02-01 00:00:00  2020-03-01 00:00:00
#
#                    304
# 0  2020-04-01 00:00:00
#
# [1 rows x 306 columns]

# %%
# Reassign index columns to dates
properties_transposed.columns = properties_transposed.iloc[0]

# %%
# see dataframe properties
properties_transposed.head()
# Out:
# 0          Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001                91449              82202.8
# 2  Barking & Dagenham  E09000002              50460.2              51085.8
# 3              Barnet  E09000003              93284.5              93190.2
# 4              Bexley  E09000004              64958.1              64787.9
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
# 2                51269              53133.5              53042.2
# 3              92247.5              90762.9                90258
# 4              64367.5              64277.7              63997.1
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
# 2              53700.3              52113.1              52232.2  ...
# 3              90107.2              91441.2              92361.3  ...
# 4              64252.3              63722.7              64432.6  ...
#
# 0  2019-07-01 00:00:00  2019-08-01 00:00:00  2019-09-01 00:00:00  \
# 0  2019-07-01 00:00:00  2019-08-01 00:00:00  2019-09-01 00:00:00
# 1               756407               813770               810455
# 2               297426               299421               304778
# 3               514668               528577               526670
# 4               338346               337523               333340
#
# 0  2019-10-01 00:00:00  2019-11-01 00:00:00  2019-12-01 00:00:00  \
# 0  2019-10-01 00:00:00  2019-11-01 00:00:00  2019-12-01 00:00:00
# 1               826227               776894               737275
# 2               304579               306390               301283
# 3               525678               522639               519306
# 4               332920               333657               336302
#
# 0  2020-01-01 00:00:00  2020-02-01 00:00:00  2020-03-01 00:00:00  \
# 0  2020-01-01 00:00:00  2020-02-01 00:00:00  2020-03-01 00:00:00
# 1               747611               777640               844989
# 2               303653               304265               304099
# 3               518542               519121               527747
# 4               334765               337760               339215
#
# 0  2020-04-01 00:00:00
# 0  2020-04-01 00:00:00
# 1               867841
# 2               283139
# 3               526553
# 4               346840
#
# [5 rows x 306 columns]

# %%
# Need to drop the row at index 0  
properties_transposed = properties_transposed.drop(0)

# %%
# We check the df one more time to see how it looks
properties_transposed.head()
# Out:
# 0          Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# 2             53700.3             52113.1             52232.2  ...
# 3             90107.2             91441.2             92361.3  ...
# 4             64252.3             63722.7             64432.6  ...
# 5             74310.5               74127               73547  ...
#
# 0 2019-07-01 00:00:00 2019-08-01 00:00:00 2019-09-01 00:00:00  \
# 1              756407              813770              810455
# 2              297426              299421              304778
# 3              514668              528577              526670
# 4              338346              337523              333340
# 5              473849              488784              501533
#
# 0 2019-10-01 00:00:00 2019-11-01 00:00:00 2019-12-01 00:00:00  \
# 1              826227              776894              737275
# 2              304579              306390              301283
# 3              525678              522639              519306
# 4              332920              333657              336302
# 5              494770              432188              427126
#
# 0 2020-01-01 00:00:00 2020-02-01 00:00:00 2020-03-01 00:00:00  \
# 1              747611              777640              844989
# 2              303653              304265              304099
# 3              518542              519121              527747
# 4              334765              337760              339215
# 5              423161              467145              461398
#
# 0 2020-04-01 00:00:00
# 1              867841
# 2              283139
# 3              526553
# 4              346840
# 5              494455
#
# [5 rows x 306 columns]

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
# Renaming columns'Unnamed' and 'NaN'
properties_transposed = properties_transposed.rename(columns = {'Unnamed: 0':'London_Districts', pd.NaT: 'ID'})

# %%
# Checking how the data looks
properties_transposed.head()
# Out:
# 0    London_Districts         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
# 3              Barnet  E09000003             93284.5             93190.2
# 4              Bexley  E09000004             64958.1             64787.9
# 5               Brent  E09000005             71306.6             72022.3
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
# 3             92247.5             90762.9               90258
# 4             64367.5             64277.7             63997.1
# 5             72015.8             72965.6               73704
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# 2             53700.3             52113.1             52232.2  ...
# 3             90107.2             91441.2             92361.3  ...
# 4             64252.3             63722.7             64432.6  ...
# 5             74310.5               74127               73547  ...
#
# 0 2019-07-01 00:00:00 2019-08-01 00:00:00 2019-09-01 00:00:00  \
# 1              756407              813770              810455
# 2              297426              299421              304778
# 3              514668              528577              526670
# 4              338346              337523              333340
# 5              473849              488784              501533
#
# 0 2019-10-01 00:00:00 2019-11-01 00:00:00 2019-12-01 00:00:00  \
# 1              826227              776894              737275
# 2              304579              306390              301283
# 3              525678              522639              519306
# 4              332920              333657              336302
# 5              494770              432188              427126
#
# 0 2020-01-01 00:00:00 2020-02-01 00:00:00 2020-03-01 00:00:00  \
# 1              747611              777640              844989
# 2              303653              304265              304099
# 3              518542              519121              527747
# 4              334765              337760              339215
# 5              423161              467145              461398
#
# 0 2020-04-01 00:00:00
# 1              867841
# 2              283139
# 3              526553
# 4              346840
# 5              494455
#
# [5 rows x 306 columns]

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
# Most important properties of tidy data are: Each column is a variable. Each row is an observation
# Result: a DataFrame with rows representing the average house price within a given month and a given district


clean_properties = pd.melt(properties_transposed, id_vars= ['London_Districts', 'ID'])

# %%
# check the data
clean_properties.head(400)
# Out:
#          London_Districts         ID          0    value
# 0          City of London  E09000001 1995-01-01    91449
# 1      Barking & Dagenham  E09000002 1995-01-01  50460.2
# 2                  Barnet  E09000003 1995-01-01  93284.5
# 3                  Bexley  E09000004 1995-01-01  64958.1
# 4                   Brent  E09000005 1995-01-01  71306.6
# ..                    ...        ...        ...      ...
# 395               Hackney  E09000012 1995-09-01  68752.5
# 396  Hammersmith & Fulham  E09000013 1995-09-01   123094
# 397              Haringey  E09000014 1995-09-01  82142.9
# 398                Harrow  E09000015 1995-09-01    83607
# 399              Havering  E09000016 1995-09-01  68108.2
#
# [400 rows x 4 columns]

# %%
# Re-name the column names
clean_properties = clean_properties.rename(columns = {0: 'Date', 'value': 'Average_price'})

# %%
# Check the data
clean_properties.head()
# Out:
#      London_Districts         ID       Date Average_price
# 0      City of London  E09000001 1995-01-01         91449
# 1  Barking & Dagenham  E09000002 1995-01-01       50460.2
# 2              Barnet  E09000003 1995-01-01       93284.5
# 3              Bexley  E09000004 1995-01-01       64958.1
# 4               Brent  E09000005 1995-01-01       71306.6

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
# check if the data types are all correct
clean_properties.dtypes
# Out:
# London_Districts            object
# ID                          object
# Date                datetime64[ns]
# Average_price               object
# dtype: object

# %%
# Average_price is NOT float type, so we need to change that by using to_numeric() 

clean_properties['Average_price'] = pd.to_numeric(clean_properties['Average_price'])

# %%
# Check the data to make sure Average_price is now a float

clean_properties.dtypes
# Out:
# London_Districts            object
# ID                          object
# Date                datetime64[ns]
# Average_price              float64
# dtype: object

# %%
# To see if there are any missing values, we should call the count() method on our DataFrame:

clean_properties.count()
# Out:
# London_Districts    14592
# ID                  13680
# Date                14592
# Average_price       13680
# dtype: int64

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
# There are mismatches between the number of entries in each column, we know there are 32 districts in London
# We can check for unique values on London_Districts column

clean_properties['London_Districts'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Unnamed: 34',
#        'Inner London', 'Outer London', 'Unnamed: 37', 'NORTH EAST',
#        'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'], dtype=object)

# %%
# There are many entries that are NOT London districts: 'Unnamed: 34','Unnamed: 37','NORTH EAST','NORTH WEST'
#'YORKS & THE HUMBER','EAST MIDLANDS','WEST MIDLANDS','EAST OF ENGLAND','LONDON','SOUTH EAST','SOUTH WEST'
#'Unnamed: 47','England'----> Next: We check what values these entries hold, if nothing valuable, it can be dropped

# Subset clean_properties on the condition: df['London_Borough'] == 'Unnamed: 34' to see the info it contains
clean_properties[clean_properties['London_Districts'] == 'Unnamed: 34'].head()
# Out:
#     London_Districts   ID       Date  Average_price
# 33       Unnamed: 34  NaN 1995-01-01            NaN
# 81       Unnamed: 34  NaN 1995-02-01            NaN
# 129      Unnamed: 34  NaN 1995-03-01            NaN
# 177      Unnamed: 34  NaN 1995-04-01            NaN
# 225      Unnamed: 34  NaN 1995-05-01            NaN

# %%
# Do the same for the other NOT London districts
clean_properties[clean_properties['London_Districts'] == 'Unnamed: 37'].head()
# Out:
#     London_Districts   ID       Date  Average_price
# 36       Unnamed: 37  NaN 1995-01-01            NaN
# 84       Unnamed: 37  NaN 1995-02-01            NaN
# 132      Unnamed: 37  NaN 1995-03-01            NaN
# 180      Unnamed: 37  NaN 1995-04-01            NaN
# 228      Unnamed: 37  NaN 1995-05-01            NaN

# %%
# Goal is to delete both entries that don't carry any info
# check how many rows have NaN as value for ID column

clean_properties[clean_properties['ID'].isna()]
# Out:
#       London_Districts   ID       Date  Average_price
# 33         Unnamed: 34  NaN 1995-01-01            NaN
# 36         Unnamed: 37  NaN 1995-01-01            NaN
# 46         Unnamed: 47  NaN 1995-01-01            NaN
# 81         Unnamed: 34  NaN 1995-02-01            NaN
# 84         Unnamed: 37  NaN 1995-02-01            NaN
# ...                ...  ...        ...            ...
# 14532      Unnamed: 37  NaN 2020-03-01            NaN
# 14542      Unnamed: 47  NaN 2020-03-01            NaN
# 14577      Unnamed: 34  NaN 2020-04-01            NaN
# 14580      Unnamed: 37  NaN 2020-04-01            NaN
# 14590      Unnamed: 47  NaN 2020-04-01            NaN
#
# [912 rows x 4 columns]

# %%
# Dealing with Null values --> 1st: filtering
# notna() will return a series of booleans, returns false if there is a null

NaN_Free_DF1 = clean_properties[clean_properties['Average_price'].notna()]
NaN_Free_DF1.head(10)
# Out:
#      London_Districts         ID       Date  Average_price
# 0      City of London  E09000001 1995-01-01    91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698
# 5             Bromley  E09000006 1995-01-01    81671.47692
# 6              Camden  E09000007 1995-01-01   120932.88810
# 7             Croydon  E09000008 1995-01-01    69158.16225
# 8              Ealing  E09000009 1995-01-01    79885.89069
# 9             Enfield  E09000010 1995-01-01    72514.69096

# %%
# see how many rows we have that have complete information: 
NaN_Free_DF1.count()
# Out:
# London_Districts    13680
# ID                  13680
# Date                13680
# Average_price       13680
# dtype: int64

# %%
# Looks Good!!! The count shows there are 13680 entries for each column
# Now, use dropna() to drop all null values

# filtering the data with NaN values
NaN_Free_DF2 = clean_properties.dropna()
NaN_Free_DF2.head(10)
# Out:
#      London_Districts         ID       Date  Average_price
# 0      City of London  E09000001 1995-01-01    91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698
# 5             Bromley  E09000006 1995-01-01    81671.47692
# 6              Camden  E09000007 1995-01-01   120932.88810
# 7             Croydon  E09000008 1995-01-01    69158.16225
# 8              Ealing  E09000009 1995-01-01    79885.89069
# 9             Enfield  E09000010 1995-01-01    72514.69096

# %%
# Let's do a count on this DataFrame object: 
NaN_Free_DF2.count()
# Out:
# London_Districts    13680
# ID                  13680
# Date                13680
# Average_price       13680
# dtype: int64

# %%
NaN_Free_DF2['London_Districts'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
# Using the .shape attribute, compare the dimenions of clean_properties, NaN_Free_DF1, and NaN_Free_DF2: 
print(clean_properties.shape)
print(NaN_Free_DF1.shape)
print(NaN_Free_DF2.shape)
# Out:
# (14592, 4)
# (13680, 4)
# (13680, 4)

# %%
# Drop the other Non London Districts

non_Districts = ['Inner London', 'Outer London', 
               'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 
               'EAST MIDLANDS', 'WEST MIDLANDS',
              'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 
              'SOUTH WEST', 'England']

# %%
# Filter Nan_Free_DF2 first on the condition that the rows' values for London_Districts is in the non_Districts list
 
NaN_Free_DF2[NaN_Free_DF2.London_Districts.isin(non_Districts)]
# Out:
#          London_Districts         ID       Date  Average_price
# 34           Inner London  E13000001 1995-01-01    78251.97650
# 35           Outer London  E13000002 1995-01-01    72958.79836
# 37             NORTH EAST  E12000001 1995-01-01    42076.35411
# 38             NORTH WEST  E12000002 1995-01-01    43958.48001
# 39     YORKS & THE HUMBER  E12000003 1995-01-01    44803.42878
# ...                   ...        ...        ...            ...
# 14586     EAST OF ENGLAND  E12000006 2020-04-01   295639.92970
# 14587              LONDON  E12000007 2020-04-01   480425.38750
# 14588          SOUTH EAST  E12000008 2020-04-01   327412.72220
# 14589          SOUTH WEST  E12000009 2020-04-01   255891.14190
# 14591             England  E92000001 2020-04-01   250873.97870
#
# [3648 rows x 4 columns]

# %%
# Get just those rows whose values for London_Districts is NOT in the non_Districts
# Just put the negation operator ~ before the filter statement


NaN_Free_DF2[~NaN_Free_DF2.London_Districts.isin(non_Districts)]
# Out:
#          London_Districts         ID       Date  Average_price
# 0          City of London  E09000001 1995-01-01   9.144898e+04
# 1      Barking & Dagenham  E09000002 1995-01-01   5.046023e+04
# 2                  Barnet  E09000003 1995-01-01   9.328452e+04
# 3                  Bexley  E09000004 1995-01-01   6.495809e+04
# 4                   Brent  E09000005 1995-01-01   7.130657e+04
# ...                   ...        ...        ...            ...
# 14572              Sutton  E09000029 2020-04-01   3.768080e+05
# 14573       Tower Hamlets  E09000030 2020-04-01   4.809838e+05
# 14574      Waltham Forest  E09000031 2020-04-01   4.403541e+05
# 14575          Wandsworth  E09000032 2020-04-01   6.072275e+05
# 14576         Westminster  E09000033 2020-04-01   1.034488e+06
#
# [10032 rows x 4 columns]

# %%
# Execute the reassignment 

NaN_Free_DF2 = NaN_Free_DF2[~NaN_Free_DF2.London_Districts.isin(non_Districts)]

# %%
# Check the data
NaN_Free_DF2.head(10)
# Out:
#      London_Districts         ID       Date  Average_price
# 0      City of London  E09000001 1995-01-01    91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698
# 5             Bromley  E09000006 1995-01-01    81671.47692
# 6              Camden  E09000007 1995-01-01   120932.88810
# 7             Croydon  E09000008 1995-01-01    69158.16225
# 8              Ealing  E09000009 1995-01-01    79885.89069
# 9             Enfield  E09000010 1995-01-01    72514.69096

# %%
NaN_Free_DF2.count()
# Out:
# London_Districts    10032
# ID                  10032
# Date                10032
# Average_price       10032
# dtype: int64

# %%
# We finally have our df

df = NaN_Free_DF2

# %%
df.head()
# Out:
#      London_Districts         ID       Date  Average_price
# 0      City of London  E09000001 1995-01-01    91448.98487
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698

# %%
df.dtypes
# Out:
# London_Districts            object
# ID                          object
# Date                datetime64[ns]
# Average_price              float64
# dtype: object

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
# I will subset Brent District prices -- assign it the result of filtering the df 
Brent_Prices = df[df['London_Districts'] == 'Brent']

# %%
# Line Plot for visualization with parameteres: kind ='line', x = 'Date', y='Average_price'
Brent_Plot = Brent_Prices.plot(kind ='line', x = 'Date', y = 'Average_price')

# The set_ylabel() method set that label to the string: 'Price'
Brent_Plot.set_ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
# Try this yourself. 
df['Year'] = df['Date'].apply(lambda month: month.year)

# Call the tail() method on df
df.tail()
# Out:
#       London_Districts         ID       Date  Average_price  Year
# 14572           Sutton  E09000029 2020-04-01   3.768080e+05  2020
# 14573    Tower Hamlets  E09000030 2020-04-01   4.809838e+05  2020
# 14574   Waltham Forest  E09000031 2020-04-01   4.403541e+05  2020
# 14575       Wandsworth  E09000032 2020-04-01   6.072275e+05  2020
# 14576      Westminster  E09000033 2020-04-01   1.034488e+06  2020

# %%
# We want to calculate the yearly mean house price for London Districts
# The groupby() method returns London_Districts and Year as indices

df_yearly_price = df.groupby(['London_Districts','Year']).mean()

# Check the data
df_yearly_price.head(10)
# Out:
#                          Average_price
# London_Districts   Year
# Barking & Dagenham 1995   51817.969390
#                    1996   51718.192690
#                    1997   55974.262309
#                    1998   60285.821083
#                    1999   65320.934441
#                    2000   77549.513290
#                    2001   88664.058223
#                    2002  112221.912482
#                    2003  142498.927800
#                    2004  158175.982483

# %%
# Reset the index for our new DataFrame df_yearly_price, and call the head() method on it

df_yearly_price = df_yearly_price.reset_index()
df_yearly_price.head()
# Out:
#      London_Districts  Year  Average_price
# 0  Barking & Dagenham  1995   51817.969390
# 1  Barking & Dagenham  1996   51718.192690
# 2  Barking & Dagenham  1997   55974.262309
# 3  Barking & Dagenham  1998   60285.821083
# 4  Barking & Dagenham  1999   65320.934441

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
# Creat a function to calculate the ratio of house prices that compare 2018 to 1998 house prices
# The function takes distritcs from the London_Districts columns as arguments

def create_price_ratio(arg):
    avg_price_1998 = float(arg['Average_price'][arg['Year']==1998]) #what is this line doing?
    avg_price_2018 = float(arg['Average_price'][arg['Year']==2018])
    ratio = avg_price_2018/avg_price_1998
    return ratio

# %%
# Let's test the function passing on the following argument

create_price_ratio(df_yearly_price[df_yearly_price['London_Districts']=='Barking & Dagenham'])
# Out:
# 4.89661861291754

# %%
# We want to do the above with all the London Districts, that is calculate the ratio 2018/1998 for each unique district
# Create an empty dict 

Ratio_per_District = {}

# %%
# A for loop that will iterate through each of the unique districts of the 'London_Districts' column of the DataFrame df_yearly_price
# .unique() returns unique values in the df

for name in df_yearly_price['London_Districts'].unique():
    
    district = df_yearly_price[df_yearly_price['London_Districts'] == name]
    Ratio_per_District[name] = create_price_ratio(district)
    
print(Ratio_per_District)
# Out:
# {'Barking & Dagenham': 4.89661861291754, 'Barnet': 4.358195917538044, 'Bexley': 4.248977046127877, 'Brent': 4.8945544971392865, 'Bromley': 4.0947846853338765, 'Camden': 4.935353408884261, 'City of London': 5.301620377587609, 'Croydon': 4.201100280024767, 'Ealing': 4.311450902121834, 'Enfield': 4.26347158349581, 'Greenwich': 4.763036347329193, 'Hackney': 6.198285561008662, 'Hammersmith & Fulham': 4.137798101936229, 'Haringey': 5.134624964136042, 'Harrow': 4.0591964329643195, 'Havering': 4.325230371335308, 'Hillingdon': 4.2002730803844575, 'Hounslow': 3.976409106143329, 'Islington': 4.844048012802298, 'Kensington & Chelsea': 5.082465066092464, 'Kingston upon Thames': 4.270549521484271, 'Lambeth': 4.957751163514063, 'Lewisham': 5.449221041059685, 'Merton': 4.741273313294604, 'Newham': 5.305390437201879, 'Redbridge': 4.471182006097364, 'Richmond upon Thames': 4.005161895721457, 'Southwark': 5.516485302379376, 'Sutton': 4.118522608573157, 'Tower Hamlets': 4.62670104006116, 'Waltham Forest': 5.83475580932281, 'Wandsworth': 4.757709347739269, 'Westminster': 5.353565392605413}

# %%
# Make a variable called df_ratios, and assign it the result of calling the DataFrame method on the dictionary final. 
df_ratios = pd.DataFrame(Ratio_per_District, index=[0])

# %%
# check the data
df_ratios.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    City of London  Croydon    Ealing   Enfield  ...    Merton   Newham  \
# 0         5.30162   4.2011  4.311451  4.263472  ...  4.741273  5.30539
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   4.471182              4.005162   5.516485  4.118523       4.626701
#
#    Waltham Forest  Wandsworth  Westminster
# 0        5.834756    4.757709     5.353565
#
# [1 rows x 33 columns]

# %%
# Now we transpose the df_ratios, and reset the index! 
df_ratios_T = df_ratios.T
df_ratios = df_ratios_T.reset_index()
df_ratios.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
# Rename the 'index' column as 'London_Districts', and the '0' column to '2018'
df_ratios.rename(columns={'index':'London_Districts', 0:'2018'}, inplace=True)
df_ratios.head()
# Out:
#      London_Districts      2018
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
# Sort in descending order and select the top 10 districts
# Make a variable called top10, assign it the result of calling sort_values() on df_ratios. 
top10 = df_ratios.sort_values(by='2018',ascending=False).head(10)
print(top10)
# Out:
#         London_Districts      2018
# 11               Hackney  6.198286
# 30        Waltham Forest  5.834756
# 27             Southwark  5.516485
# 22              Lewisham  5.449221
# 32           Westminster  5.353565
# 24                Newham  5.305390
# 6         City of London  5.301620
# 13              Haringey  5.134625
# 19  Kensington & Chelsea  5.082465
# 21               Lambeth  4.957751

# %%
# Finally, it's time to plot the districts that have seen the greatest changes in price
# Make a variable called a bar_graph assign it the result of filtering top10 on 'London_Districts' and '2018'
# then calling plot(), with the parameter kind = 'bar'

bar_graph = top10[['London_Districts','2018']].plot(kind='bar')

bar_graph.set_xticklabels(top10.London_Districts)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(0, 0, 'Waltham Forest'),
#  Text(0, 0, 'Southwark'),
#  Text(0, 0, 'Lewisham'),
#  Text(0, 0, 'Westminster'),
#  Text(0, 0, 'Newham'),
#  Text(0, 0, 'City of London'),
#  Text(0, 0, 'Haringey'),
#  Text(0, 0, 'Kensington & Chelsea'),
#  Text(0, 0, 'Lambeth')]

# %% [markdown]
# ### 4. Conclusion
#
# The housing price in London districts increased at least four times over the last 20 years. In Hackney, the most expensive district in London as of 2018, the average house price increased 6.2 times compared to the 1998 house market. To buy a house in one of the top 10 most expensive districts in London today means paying on average 5 times what that same house cost 20 years ago.
